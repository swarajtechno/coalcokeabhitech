# %%
import pandas as pd
import numpy as np

# %%
# Define the D matrix
D = np.array([
    [26, 20, 39, 0, 15, 0, 0],
    [26, 20, 39, 0, 15, 0, 0],
    [26, 20, 39, 0, 15, 0, 0],
    [26, 20, 39, 0, 15, 0, 0],
    [22, 17, 30, 0, 16, 15, 0],
    [22, 17, 30, 0, 16, 15, 0],
    [22, 17, 30, 0, 16, 15, 0],
    [22, 17, 30, 0, 16, 15, 0],
    [22, 17, 30, 0, 16, 15, 0],
    [24, 20, 32, 0, 16, 8, 0],
    [24, 20, 32, 0, 16, 8, 0],
    [24, 20, 32, 0, 16, 8, 0],
    [24, 20, 32, 0, 16, 8, 0],
    [24, 20, 32, 0, 16, 8, 0],
    [22, 26, 32, 0, 20, 0, 0],
    [16, 18, 34, 14, 18, 0, 0],
    [16, 18, 34, 14, 18, 0, 0],
    [16, 18, 34, 14, 18, 0, 0],
    [22, 20, 38, 0, 20, 0, 0],
    [17, 17, 38, 14, 14, 0, 0],
    [17, 17, 38, 14, 14, 0, 0],
    [17, 17, 38, 14, 14, 0, 0],
    [17, 17, 38, 14, 14, 0, 0],
    [17, 17, 38, 14, 14, 0, 0],
    [17, 17, 38, 14, 14, 0, 0],
    [17, 17, 38, 14, 14, 0, 0],
    [17, 17, 38, 14, 14, 0, 0],
    [17, 17, 38, 14, 14, 0, 0],
    [18, 19, 36, 19, 8, 0, 0],
    [18, 19, 36, 19, 8, 0, 0],
    [18, 19, 36, 19, 8, 0, 0],
    [18, 19, 36, 19, 8, 0, 0],
    [18, 19, 36, 19, 8, 0, 0],
    [18, 19, 36, 19, 8, 0, 0],
    [18, 19, 36, 19, 8, 0, 0],
    [18, 19, 36, 19, 8, 0, 0],
    [18, 19, 36, 19, 8, 0, 0],
    [18, 25, 42, 0, 15, 0, 0],
    [18, 25, 42, 0, 15, 0, 0],
    [18, 25, 42, 0, 15, 0, 0],
    [18, 25, 42, 0, 15, 0, 0],
    [18, 25, 42, 0, 15, 0, 0],
    [18, 25, 42, 0, 15, 0, 0],
    [18, 25, 42, 0, 15, 0, 0],
    [18, 25, 42, 0, 15, 0, 0],
    [18, 25, 42, 0, 15, 0, 0],
    [22, 22, 35, 0, 16, 0, 5],
    [22, 22, 35, 0, 16, 0, 5],
    [22, 22, 35, 0, 16, 0, 5],
    [22, 22, 35, 0, 16, 0, 5],
    [22, 22, 35, 0, 16, 0, 5],
    [22, 22, 35, 0, 16, 0, 5]
])

# %%
D.shape
# Out:
# (52, 7)

# %%
# Define the P matrix
P = np.array([
    [18.25, 21, 10, 21, 25, 950, 1.2, 85, 445, 480, 505, 60, 0.6, 0.065, 7],
    [18.5, 25.5, 10, 26, 28, 3750, 1, 65, 435, 470, 505, 70, 0.65, 0.07, 3],
    [11.86, 23.04, 10, 18, 25, 1200, 1.25, 68, 400, 425, 495, 85, 0.45, 0.056, 7.5],
    [9.8, 28, 10, 19, 25, 2000, 1.1, 80, 400, 450, 485, 85, 0.48, 0.06, 7],
    [8.1, 24.4, 9, 20, 30, 300, 1.15, 78, 420, 455, 485, 65, 0.44, 0.061, 7],
    [11.86, 23.04, 10.35, 22, 40, 836, 85.82, 46.29, 378, 425, 480, 81.9, 0.34, 0.08, 6],
    [11.86, 23.04, 10.35, 21, 44, 836, 85.82, 46.29, 378, 425, 480, 81.9, 0.34, 0.08, 6],
    [11.86, 23.04, 10.35, 20, 47, 836, 85.82, 46.29, 378, 425, 480, 81.9, 0.34, 0.08, 6],
    [11.86, 23.04, 10.35, 20, 37, 836, 85.82, 46.29, 378, 425, 480, 81.9, 0.34, 0.08, 6],
    [11.86, 23.04, 10.35, 20, 29, 836, 85.82, 46.29, 378, 425, 480, 81.9, 0.34, 0.08, 6],
    [11.86, 23.04, 10.35, 17, 14, 836, 85.82, 46.29, 378, 425, 480, 81.9, 0.34, 0.08, 6],
  [11.57, 23.29, 10.36, 15, 10, 763, 85.98, 46.2, 368, 418,495, 77, 0.39, 0.07, 6],
  [11.57, 23.29, 10.36, 23, 41, 763, 85.98, 46.2, 368, 418,495, 77, 0.39, 0.07, 6],
  [11.57, 23.29, 10.36, 19, 25, 763, 85.98, 46.2, 368, 418,495, 77, 0.39, 0.07, 6],
  [11.57, 23.29, 10.36, 21, 20, 763, 85.98, 46.2, 368, 418,495, 77, 0.39, 0.07, 6],
  [11.57, 23.29, 10.36, 19, 30, 763, 85.98, 46.2, 368, 418,495, 77, 0.39, 0.07, 6],
  [11.57, 23.29, 10.36, 17, 8, 763, 85.98, 46.2, 368, 418,495, 77, 0.39, 0.07, 6]
])

# %%
result.shape
# Out:
# (52, 15)

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn.metrics import accuracy_score, mean_squared_error

# %%
X = B
Y = result
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
import numpy as np

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

#
model = RandomForestRegressor(
    n_estimators=200,
    random_state=42,
)

model.fit(X_train, y_train)

y_pred = model.predict(X_test)
mse = np.mean((y_test - y_pred) ** 2)
print(f"Mean Squared Error: {mse:.2f}")
# Out:
# Mean Squared Error: 82.15

# %%
Test=np.array([
    [26, 20, 39, 0, 15, 0, 0]
])

# %%
Test_mult=np.dot(Test,P)

# %%
Test_mult.shape
# Out:
# (1, 15)

# %%
Pred1=model.predict(Test_mult)

# %%
import numpy as np

# Print type and shape of predictions
print("Type of predictions:", type(Pred1))
print("Shape of predictions:", Pred1.shape)

# Print the first few entries of predictions to see its content
print("First few entries of predictions:", Pred1[:5])
# Out:
# Type of predictions: <class 'numpy.ndarray'>
# Shape of predictions: (1, 15)
# First few entries of predictions: [[1.17264000e+01 2.30051000e+01 1.05141000e+01 1.89925047e+01
#   2.73193759e+01 1.03261500e+03 8.57201000e+01 4.63242000e+01
#   3.99035000e+02 4.23690000e+02 4.71820000e+02 8.06940000e+01
#   3.59650000e-01 7.47500000e-02 6.00000000e+00]]

# %%
print(Pred1)
# Out:
# [[1.17264000e+01 2.30051000e+01 1.05141000e+01 1.89925047e+01
#   2.73193759e+01 1.03261500e+03 8.57201000e+01 4.63242000e+01
#   3.99035000e+02 4.23690000e+02 4.71820000e+02 8.06940000e+01
#   3.59650000e-01 7.47500000e-02 6.00000000e+00]]

# %%
# 11.86, 23.04, 10.03, 18, 28, 903, 85.5, 46.38, 408, 423, 482, 78.9, 0.38, 0.06, 6

# %%
# Coal Ash	Coal VM	Coal Moisture	Max. Contraction	Max.   Expansion	Max. fluidity 	MMR	HGI	Softening temperature (degC)	Resolidification temp range (degC)	Plastic range (degC)	Sulpher	Phosphorous	CSN

#Blended Coal Ash	Blended Coal VM	Blended Coal Moisture	Max. Contraction	Max.   Expansion	Max. fluidity 	"Crushing index<3.15mm"	"Crushing Index<0.5mm"	Softening temperature (degC)	Resolidification temp range (degC)	Plastic range (degC)	Sulpher	Phosphorous	CSN

# %%
y_train_pred = model.predict(X_train)
y_test_pred = model.predict(X_test)


def mean_absolute_percentage_error(y_true, y_pred):
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

mape_train = mean_absolute_percentage_error(y_train, y_train_pred)
mape_test = mean_absolute_percentage_error(y_test, y_test_pred)

# Calculate accuracy
accuracy_train = 100 - mape_train
accuracy_test = 100 - mape_test

# Print the results
print(f"Accuracy on Training set: {accuracy_train:.2f}%")
print(f"Accuracy on Test set: {accuracy_test:.2f}%")
# Out:
# Accuracy on Training set: 97.11%
# Accuracy on Test set: 96.45%

# %%
# List of coal blends
coal_blends = ["Bhelatand", "West Bokaro", "Illawarra", "Sonoma", "Poetrel", "Blue Creek", "PCI"]

# Initialize an empty dictionary to store the inputs
user_inputs = {}
total = 0
# Loop through the coal blends to get inputs
while(total!=100):
    for blend in coal_blends:
        # Prompt the user for input
        user_input = int(input(f"Enter integer value for {blend}: "))
        # Store the input in the dictionary
        user_inputs[blend] = user_input
        total = total + user_input
    if(total != 100):
        print("Blend ratios do not add up to 100, try again")
    else:
        break


# Calculate Test_mult using user inputs
Test_mult = np.dot(user_input_values.reshape(1, -1), P)
predictions=model.predict(Test_mult)


parameters = [
    "Blended Coal Ash", 
    "Blended Coal VM", 
    "Blended Coal Moisture", 
    "Max. Contraction", 
    "Max. Expansion", 
    "Max. Fluidity", 
    "Crushing index<3.15mm", 
    "Crushing Index<0.5mm", 
    "Softening temperature (degC)", 
    "Resolidification temp min (degC)", 
    "Resolidification temp max (degC)",
    "Plastic range (degC)", 
    "Sulfur", 
    "Phosphorus", 
    "CSN"
]

# Flatten the predictions array
predictions_flat = predictions.flatten()

# Print the predictions with corresponding parameter names
print("Predicted Parameters:")
for param, value in zip(parameters, predictions_flat):
    print(f"{param}: {value}")

#[26, 20, 39, 0, 15, 0, 0]
# Out:
# Enter integer value for Bhelatand: 10
# Enter integer value for West Bokaro: 5
# Enter integer value for Illawarra: 5
# Enter integer value for Sonoma: 10
# Enter integer value for Poetrel: 30
# Enter integer value for Blue Creek: 40
# Enter integer value for PCI: 0
# Predicted Parameters:
# Blended Coal Ash: 11.726400000000002
# Blended Coal VM: 23.005100000000017
# Blended Coal Moisture: 10.514099999999974
# Max. Contraction: 18.992504689754686
# Max. Expansion: 27.3193759018759
# Max. Fluidity: 1032.615
# Crushing index<3.15mm: 85.72009999999996
# Crushing Index<0.5mm: 46.324199999999976
# Softening temperature (degC): 399.035
# Resolidification temp min (degC): 423.69
# Resolidification temp max (degC): 471.82
# Plastic range (degC): 80.6940000000001
# Sulfur: 0.35965000000000025
# Phosphorus: 0.0747500000000001
# CSN: 6.0

# %%
# 11.86, 23.04, 10.03, 18, 28, 903, 85.5, 46.38, 408, 423, 482, 78.9, 0.38, 0.06, 6
